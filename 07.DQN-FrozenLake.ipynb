# %% [markdown]
# # 06.DQN

# %% [markdown]
# 1）使用随机权重$（w←1.0）$初始化目标网络$Q(s, a, w)$和网络$\hat Q(s, a, w)$，$Q$和$\hat Q$相同，清空回放缓冲区。
#
# 2）以概率ε选择一个随机动作a，否则 $a=argmaxQ(s,a,w)$。
#
# 3）在模拟器中执行动作a，观察奖励r和下一个状态s'。
#
# 4）将转移过程(s, a, r, s')存储在回放缓冲区中。
#
# 5）从回放缓冲区中采样一个随机的小批量转移过程。
#
# 6）对于回放缓冲区中的每个转移过程，如果片段在此步结束，则计算目标$y=r$，否则计算$y=r+\gamma max \hat Q(s, a, w)$ 。
#
# 7）计算损失：$L=(Q(s, a, w)–y)^2$。
#
# 8）固定网络$\hat Q(s, a, w)$不变，通过最小化模型参数的损失，使用SGD算法更新$Q(s, a)$。
#
# 9）每N步，将权重从目标网络$Q$复制到$\hat Q(s, a, w)$ 。
#
# 10）从步骤2开始重复，直到收敛为止。

# %%
import collections
import copy
import math
import random
import time
from collections import defaultdict

import gym
import gym.spaces
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from gym.envs.toy_text import frozen_lake
from torch.utils.tensorboard import SummaryWriter

# %%
class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, q_table_size):
        super(Net, self).__init__()

        self.net = nn.Sequential(
            # 输入为状态，样本为（1*n）
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            # nn.Linear(hidden_size, hidden_size),
            # nn.ReLU(),
            nn.Linear(hidden_size, q_table_size),
        )

    def forward(self, state):
        return self.net(state)


class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space, gym.spaces.Discrete)
        shape = (env.observation_space.n,)
        self.observation_space = gym.spaces.Box(0.0, 1.0, shape, dtype=np.float32)

    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation] = 1.0
        return res

# %% [markdown]
# # ReplayBuffer

# %%
class ReplayBuffer:
    def __init__(self, queue_size, replay_time):
        self.queue = []
        self.queue_size = queue_size
        self.replay_time = replay_time

    def get_batch_queue(self, env, action_trigger, batch_size, epsilon):
        def insert_sample_to_queue(env):
            state, info = env.reset()
            stop = 0

            while True:
                if np.random.uniform(0, 1, 1) > epsilon:
                    action = env.action_space.sample()
                else:
                    action = action_trigger(state)

                next_state, reward, terminated, truncated, info = env.step(action)
                self.queue.append([state, action, next_state, reward, terminated])
                state = next_state
                if terminated:
                    state, info = env.reset()
                    stop += 1
                    continue
                if stop >= replay_time:
                    break

        def init_queue(env):
            while True:
                insert_sample_to_queue(env)
                if len(self.queue) >= self.queue_size:
                    break

        init_queue(env)
        insert_sample_to_queue(env)
        self.queue = self.queue[-self.queue_size :]

        return random.sample(self.queue, batch_size)

# %% [markdown]
# # DQN

# %%
class DQN:
    def __init__(self, env, obs_size, hidden_size, q_table_size):
        self.env = env
        self.net = Net(obs_size, hidden_size, q_table_size)
        self.tgt_net = Net(obs_size, hidden_size, q_table_size)

    # 更新net参数
    def update_net_parameters(self, update=True):
        self.net.load_state_dict(self.tgt_net.state_dict())

    def get_action_trigger(self, state):
        state = torch.Tensor(state)
        action = int(torch.argmax(self.tgt_net(state).detach()))
        return action

    # 计算y_hat_and_y
    def calculate_y_hat_and_y(self, batch, gamma):
        y = []
        action_sapce = []
        state_sapce = []

        for state, action, next_state, reward, terminated in batch:
            q_table_net = self.net(torch.Tensor(next_state)).detach()
            y.append(reward + (1 - terminated) * gamma * float(torch.max(q_table_net)))
            action_sapce.append(action)
            state_sapce.append(state)
        y_hat = self.tgt_net(torch.Tensor(np.array(state_sapce)))
        y_hat = y_hat.gather(1, torch.LongTensor(action_sapce).reshape(-1, 1))
        return y_hat.reshape(-1), torch.tensor(y)

    def predict_reward(self):
        state, info = env.reset()
        step = 0
        reward_space = []

        while True:
            step += 1
            state = torch.Tensor(state)
            action = int(torch.argmax(self.net(state).detach()))
            next_state, reward, terminated, truncated, info = env.step(action)
            reward_space.append(reward)
            state = next_state
            if terminated:
                state, info = env.reset()
                continue
            if step >= 100:
                break
        return float(np.mean(reward_space))

# %% [markdown]
# ## 训练

# %%
hidden_size = 64
queue_size = 500
replay_time = 50

## 初始化环境
env = frozen_lake.FrozenLakeEnv(is_slippery=False)
env.spec = gym.spec("FrozenLake-v1")
env = gym.wrappers.TimeLimit(env, max_episode_steps=100)
env = DiscreteOneHotWrapper(env)

## 初始化buffer
replay_buffer = ReplayBuffer(queue_size, replay_time)

## 初始化dqn
obs_size = env.observation_space.shape[0]
q_table_size = env.action_space.n
dqn = DQN(env, obs_size, hidden_size, q_table_size)

# 定义优化器
opt = optim.Adam(dqn.tgt_net.parameters(), lr=0.01)

# 定义损失函数
loss = nn.MSELoss()

writer = SummaryWriter(log_dir="logs/DQN/FrozenLake", comment="test1")

# %%
batch_size = 256
epsilon = 0.8
epochs = 200
gamma = 0.9

# %%
for epoch in range(epochs):
    batch = replay_buffer.get_batch_queue(
        env, dqn.get_action_trigger, batch_size, epsilon
    )
    y_hat, y = dqn.calculate_y_hat_and_y(batch, gamma)
    l = loss(y_hat, y)

    # 反向传播
    opt.zero_grad()
    l.backward()
    opt.step()

    if epoch % 10 == 0 and epoch != 0:
        dqn.update_net_parameters()

    predict_reward = dqn.predict_reward()
    writer.add_scalars(
        "MSE", {"loss": l.item(), "predict_reward": predict_reward}, epoch
    )

    print(
        "epoch:{},  MSE: {}, epsilon: {}, 100 steps reward: {}".format(
            epoch, l, epsilon, predict_reward
        )
    )
# Out:
# epoch:0,  MSE: 0.001773191150277853, epsilon: 0.8, 100 steps reward: 0.0
# epoch:1,  MSE: 0.0017909626476466656, epsilon: 0.8, 100 steps reward: 0.0
# epoch:2,  MSE: 0.0009793620556592941, epsilon: 0.8, 100 steps reward: 0.0
# epoch:3,  MSE: 0.0009744567214511335, epsilon: 0.8, 100 steps reward: 0.0
# epoch:4,  MSE: 0.00034428309299983084, epsilon: 0.8, 100 steps reward: 0.0
# epoch:5,  MSE: 0.002873851917684078, epsilon: 0.8, 100 steps reward: 0.0
# epoch:6,  MSE: 0.0007235623197630048, epsilon: 0.8, 100 steps reward: 0.0
# epoch:7,  MSE: 0.0003816983080469072, epsilon: 0.8, 100 steps reward: 0.0
# epoch:8,  MSE: 0.0005821200320497155, epsilon: 0.8, 100 steps reward: 0.0
# epoch:9,  MSE: 0.00035790519905276597, epsilon: 0.8, 100 steps reward: 0.0
# epoch:10,  MSE: 0.00022066906967666, epsilon: 0.8, 100 steps reward: 0.0
# epoch:11,  MSE: 0.0006167429382912815, epsilon: 0.8, 100 steps reward: 0.0
# epoch:12,  MSE: 0.0015119798481464386, epsilon: 0.8, 100 steps reward: 0.0
# epoch:13,  MSE: 0.000917917350307107, epsilon: 0.8, 100 steps reward: 0.0
# epoch:14,  MSE: 0.0010128070134669542, epsilon: 0.8, 100 steps reward: 0.0
# epoch:15,  MSE: 0.0041155824437737465, epsilon: 0.8, 100 steps reward: 0.0
# epoch:16,  MSE: 0.0005692602135241032, epsilon: 0.8, 100 steps reward: 0.0
# epoch:17,  MSE: 0.0016796800773590803, epsilon: 0.8, 100 steps reward: 0.0
# epoch:18,  MSE: 0.000548598647583276, epsilon: 0.8, 100 steps reward: 0.0
# epoch:19,  MSE: 0.00707522127777338, epsilon: 0.8, 100 steps reward: 0.0
# epoch:20,  MSE: 0.0011918069794774055, epsilon: 0.8, 100 steps reward: 0.0
# epoch:21,  MSE: 0.0028662486001849174, epsilon: 0.8, 100 steps reward: 0.0
# epoch:22,  MSE: 0.0003382361028343439, epsilon: 0.8, 100 steps reward: 0.0
# epoch:23,  MSE: 0.0006438173586502671, epsilon: 0.8, 100 steps reward: 0.0
# epoch:24,  MSE: 0.0005948693142272532, epsilon: 0.8, 100 steps reward: 0.0
# epoch:25,  MSE: 0.00039067972102202475, epsilon: 0.8, 100 steps reward: 0.0
# epoch:26,  MSE: 0.003103753086179495, epsilon: 0.8, 100 steps reward: 0.0
# epoch:27,  MSE: 0.0005362738156691194, epsilon: 0.8, 100 steps reward: 0.0
# epoch:28,  MSE: 0.00033943093148991466, epsilon: 0.8, 100 steps reward: 0.0
# epoch:29,  MSE: 0.0009810462361201644, epsilon: 0.8, 100 steps reward: 0.0
# epoch:30,  MSE: 0.0027729603461921215, epsilon: 0.8, 100 steps reward: 0.0
# epoch:31,  MSE: 0.0013334383256733418, epsilon: 0.8, 100 steps reward: 0.0
# epoch:32,  MSE: 0.0015062224119901657, epsilon: 0.8, 100 steps reward: 0.0
# epoch:33,  MSE: 0.0012227552942931652, epsilon: 0.8, 100 steps reward: 0.0
# epoch:34,  MSE: 0.0012831552885472775, epsilon: 0.8, 100 steps reward: 0.0
# epoch:35,  MSE: 0.0025510864797979593, epsilon: 0.8, 100 steps reward: 0.0
# epoch:36,  MSE: 0.0030656575690954924, epsilon: 0.8, 100 steps reward: 0.0
# epoch:37,  MSE: 0.002189221791923046, epsilon: 0.8, 100 steps reward: 0.0
# epoch:38,  MSE: 0.0020033966284245253, epsilon: 0.8, 100 steps reward: 0.0
# epoch:39,  MSE: 0.00989224947988987, epsilon: 0.8, 100 steps reward: 0.0
# epoch:40,  MSE: 0.005511884111911058, epsilon: 0.8, 100 steps reward: 0.0
# epoch:41,  MSE: 0.01183861494064331, epsilon: 0.8, 100 steps reward: 0.0
# epoch:42,  MSE: 0.006681433413177729, epsilon: 0.8, 100 steps reward: 0.0
# epoch:43,  MSE: 0.020224228501319885, epsilon: 0.8, 100 steps reward: 0.0
# epoch:44,  MSE: 0.014569730497896671, epsilon: 0.8, 100 steps reward: 0.0
# epoch:45,  MSE: 0.007211180403828621, epsilon: 0.8, 100 steps reward: 0.0
# epoch:46,  MSE: 0.004242250695824623, epsilon: 0.8, 100 steps reward: 0.0
# epoch:47,  MSE: 0.0072035775519907475, epsilon: 0.8, 100 steps reward: 0.0
# epoch:48,  MSE: 0.006637452635914087, epsilon: 0.8, 100 steps reward: 0.0
# epoch:49,  MSE: 0.0007711361977271736, epsilon: 0.8, 100 steps reward: 0.0
# epoch:50,  MSE: 0.0004163280827924609, epsilon: 0.8, 100 steps reward: 0.0
# epoch:51,  MSE: 0.0006537202862091362, epsilon: 0.8, 100 steps reward: 0.0
# epoch:52,  MSE: 0.0012485551415011287, epsilon: 0.8, 100 steps reward: 0.0
# epoch:53,  MSE: 0.00079136504791677, epsilon: 0.8, 100 steps reward: 0.0
# epoch:54,  MSE: 0.001059414236806333, epsilon: 0.8, 100 steps reward: 0.0
# epoch:55,  MSE: 0.0011734907748177648, epsilon: 0.8, 100 steps reward: 0.0
# epoch:56,  MSE: 0.0019782977178692818, epsilon: 0.8, 100 steps reward: 0.0
# epoch:57,  MSE: 0.0014792359434068203, epsilon: 0.8, 100 steps reward: 0.0
# epoch:58,  MSE: 0.0016717314720153809, epsilon: 0.8, 100 steps reward: 0.0
# epoch:59,  MSE: 0.0021792661864310503, epsilon: 0.8, 100 steps reward: 0.0
# epoch:60,  MSE: 0.0010953801684081554, epsilon: 0.8, 100 steps reward: 0.0
# epoch:61,  MSE: 0.0011735144071280956, epsilon: 0.8, 100 steps reward: 0.0
# epoch:62,  MSE: 0.0018945399206131697, epsilon: 0.8, 100 steps reward: 0.0
# epoch:63,  MSE: 0.0029504781123250723, epsilon: 0.8, 100 steps reward: 0.0
# epoch:64,  MSE: 0.02105110138654709, epsilon: 0.8, 100 steps reward: 0.0
# epoch:65,  MSE: 0.01646079309284687, epsilon: 0.8, 100 steps reward: 0.0
# epoch:66,  MSE: 0.0016127144917845726, epsilon: 0.8, 100 steps reward: 0.0
# epoch:67,  MSE: 0.0042702145874500275, epsilon: 0.8, 100 steps reward: 0.0
# epoch:68,  MSE: 0.0009059881558641791, epsilon: 0.8, 100 steps reward: 0.0
# epoch:69,  MSE: 0.0006817944813519716, epsilon: 0.8, 100 steps reward: 0.0
# epoch:70,  MSE: 0.0009188420954160392, epsilon: 0.8, 100 steps reward: 0.0
# epoch:71,  MSE: 0.0018797232769429684, epsilon: 0.8, 100 steps reward: 0.0
# epoch:72,  MSE: 0.002517526503652334, epsilon: 0.8, 100 steps reward: 0.0
# epoch:73,  MSE: 0.0010888756951317191, epsilon: 0.8, 100 steps reward: 0.0
# epoch:74,  MSE: 0.001490634516812861, epsilon: 0.8, 100 steps reward: 0.0
# epoch:75,  MSE: 0.001266207080334425, epsilon: 0.8, 100 steps reward: 0.0
# epoch:76,  MSE: 0.0029656493570655584, epsilon: 0.8, 100 steps reward: 0.0
# epoch:77,  MSE: 0.002084151841700077, epsilon: 0.8, 100 steps reward: 0.0
# epoch:78,  MSE: 0.0021865260787308216, epsilon: 0.8, 100 steps reward: 0.0
# epoch:79,  MSE: 0.00391754973679781, epsilon: 0.8, 100 steps reward: 0.0
# epoch:80,  MSE: 0.00572280865162611, epsilon: 0.8, 100 steps reward: 0.0
# epoch:81,  MSE: 0.01238909363746643, epsilon: 0.8, 100 steps reward: 0.0
# epoch:82,  MSE: 0.011748495511710644, epsilon: 0.8, 100 steps reward: 0.0
# epoch:83,  MSE: 0.007240389008074999, epsilon: 0.8, 100 steps reward: 0.0
# epoch:84,  MSE: 0.005816732067614794, epsilon: 0.8, 100 steps reward: 0.0
# epoch:85,  MSE: 0.01183425635099411, epsilon: 0.8, 100 steps reward: 0.0
# epoch:86,  MSE: 0.01011616364121437, epsilon: 0.8, 100 steps reward: 0.0
# epoch:87,  MSE: 0.009669885039329529, epsilon: 0.8, 100 steps reward: 0.0
# epoch:88,  MSE: 0.008039630949497223, epsilon: 0.8, 100 steps reward: 0.0
# epoch:89,  MSE: 0.03881645202636719, epsilon: 0.8, 100 steps reward: 0.0
# epoch:90,  MSE: 0.011239760555326939, epsilon: 0.8, 100 steps reward: 0.0
# epoch:91,  MSE: 0.025006920099258423, epsilon: 0.8, 100 steps reward: 0.0
# epoch:92,  MSE: 0.05085224285721779, epsilon: 0.8, 100 steps reward: 0.0
# epoch:93,  MSE: 0.038335904479026794, epsilon: 0.8, 100 steps reward: 0.0
# epoch:94,  MSE: 0.02934698387980461, epsilon: 0.8, 100 steps reward: 0.0
# epoch:95,  MSE: 0.017916090786457062, epsilon: 0.8, 100 steps reward: 0.0
# epoch:96,  MSE: 0.028967253863811493, epsilon: 0.8, 100 steps reward: 0.0
# epoch:97,  MSE: 0.010368712246418, epsilon: 0.8, 100 steps reward: 0.0
# epoch:98,  MSE: 0.024043014273047447, epsilon: 0.8, 100 steps reward: 0.0
# epoch:99,  MSE: 0.008159640245139599, epsilon: 0.8, 100 steps reward: 0.0
# epoch:100,  MSE: 0.026381734758615494, epsilon: 0.8, 100 steps reward: 0.0
# epoch:101,  MSE: 0.020509857684373856, epsilon: 0.8, 100 steps reward: 0.0
# epoch:102,  MSE: 0.027214648202061653, epsilon: 0.8, 100 steps reward: 0.0
# epoch:103,  MSE: 0.022681958973407745, epsilon: 0.8, 100 steps reward: 0.0
# epoch:104,  MSE: 0.024124786257743835, epsilon: 0.8, 100 steps reward: 0.0
# epoch:105,  MSE: 0.024802226573228836, epsilon: 0.8, 100 steps reward: 0.0
# epoch:106,  MSE: 0.02717605046927929, epsilon: 0.8, 100 steps reward: 0.0
# epoch:107,  MSE: 0.05991945043206215, epsilon: 0.8, 100 steps reward: 0.0
# epoch:108,  MSE: 0.06465917080640793, epsilon: 0.8, 100 steps reward: 0.0
# epoch:109,  MSE: 0.029421325773000717, epsilon: 0.8, 100 steps reward: 0.0
# epoch:110,  MSE: 0.027208171784877777, epsilon: 0.8, 100 steps reward: 0.16
# epoch:111,  MSE: 0.07399699091911316, epsilon: 0.8, 100 steps reward: 0.16
# epoch:112,  MSE: 0.060056425631046295, epsilon: 0.8, 100 steps reward: 0.16
# epoch:113,  MSE: 0.04102933779358864, epsilon: 0.8, 100 steps reward: 0.16
# epoch:114,  MSE: 0.03206203132867813, epsilon: 0.8, 100 steps reward: 0.16
# epoch:115,  MSE: 0.0296332947909832, epsilon: 0.8, 100 steps reward: 0.16
# epoch:116,  MSE: 0.030237220227718353, epsilon: 0.8, 100 steps reward: 0.16
# epoch:117,  MSE: 0.028541790321469307, epsilon: 0.8, 100 steps reward: 0.16
# epoch:118,  MSE: 0.021162543445825577, epsilon: 0.8, 100 steps reward: 0.16
# epoch:119,  MSE: 0.032029859721660614, epsilon: 0.8, 100 steps reward: 0.16
# epoch:120,  MSE: 0.017413953319191933, epsilon: 0.8, 100 steps reward: 0.0
# epoch:121,  MSE: 0.047149285674095154, epsilon: 0.8, 100 steps reward: 0.0
# epoch:122,  MSE: 0.034643761813640594, epsilon: 0.8, 100 steps reward: 0.0
# epoch:123,  MSE: 0.0654643103480339, epsilon: 0.8, 100 steps reward: 0.0
# epoch:124,  MSE: 0.03645787388086319, epsilon: 0.8, 100 steps reward: 0.0
# epoch:125,  MSE: 0.028446756303310394, epsilon: 0.8, 100 steps reward: 0.0
# epoch:126,  MSE: 0.044133372604846954, epsilon: 0.8, 100 steps reward: 0.0
# epoch:127,  MSE: 0.031132426112890244, epsilon: 0.8, 100 steps reward: 0.0
# epoch:128,  MSE: 0.03664354234933853, epsilon: 0.8, 100 steps reward: 0.0
# epoch:129,  MSE: 0.03311661258339882, epsilon: 0.8, 100 steps reward: 0.0
# epoch:130,  MSE: 0.038966454565525055, epsilon: 0.8, 100 steps reward: 0.0
# epoch:131,  MSE: 0.07722561061382294, epsilon: 0.8, 100 steps reward: 0.0
# epoch:132,  MSE: 0.06182046979665756, epsilon: 0.8, 100 steps reward: 0.0
# epoch:133,  MSE: 0.06386212259531021, epsilon: 0.8, 100 steps reward: 0.0
# epoch:134,  MSE: 0.06693953275680542, epsilon: 0.8, 100 steps reward: 0.0
# epoch:135,  MSE: 0.05735816806554794, epsilon: 0.8, 100 steps reward: 0.0
# epoch:136,  MSE: 0.11093156784772873, epsilon: 0.8, 100 steps reward: 0.0
# epoch:137,  MSE: 0.07791213691234589, epsilon: 0.8, 100 steps reward: 0.0
# epoch:138,  MSE: 0.08253753930330276, epsilon: 0.8, 100 steps reward: 0.0
# epoch:139,  MSE: 0.07047399878501892, epsilon: 0.8, 100 steps reward: 0.0
# epoch:140,  MSE: 0.062078241258859634, epsilon: 0.8, 100 steps reward: 0.16
# epoch:141,  MSE: 0.0329761877655983, epsilon: 0.8, 100 steps reward: 0.16
# epoch:142,  MSE: 0.03717069327831268, epsilon: 0.8, 100 steps reward: 0.16
# epoch:143,  MSE: 0.03563334420323372, epsilon: 0.8, 100 steps reward: 0.16
# epoch:144,  MSE: 0.038659363985061646, epsilon: 0.8, 100 steps reward: 0.16
# epoch:145,  MSE: 0.033265020698308945, epsilon: 0.8, 100 steps reward: 0.16
# epoch:146,  MSE: 0.022453218698501587, epsilon: 0.8, 100 steps reward: 0.16
# epoch:147,  MSE: 0.025868181139230728, epsilon: 0.8, 100 steps reward: 0.16
# epoch:148,  MSE: 0.01851765438914299, epsilon: 0.8, 100 steps reward: 0.16
# epoch:149,  MSE: 0.019573237746953964, epsilon: 0.8, 100 steps reward: 0.16
# epoch:150,  MSE: 0.021183401346206665, epsilon: 0.8, 100 steps reward: 0.0
# epoch:151,  MSE: 0.01875861920416355, epsilon: 0.8, 100 steps reward: 0.0
# epoch:152,  MSE: 0.03804687410593033, epsilon: 0.8, 100 steps reward: 0.0
# epoch:153,  MSE: 0.019300159066915512, epsilon: 0.8, 100 steps reward: 0.0
# epoch:154,  MSE: 0.028597701340913773, epsilon: 0.8, 100 steps reward: 0.0
# epoch:155,  MSE: 0.02651771903038025, epsilon: 0.8, 100 steps reward: 0.0
# epoch:156,  MSE: 0.01984068565070629, epsilon: 0.8, 100 steps reward: 0.0
# epoch:157,  MSE: 0.02021755836904049, epsilon: 0.8, 100 steps reward: 0.0
# epoch:158,  MSE: 0.012626087293028831, epsilon: 0.8, 100 steps reward: 0.0
# epoch:159,  MSE: 0.012080100364983082, epsilon: 0.8, 100 steps reward: 0.0
# epoch:160,  MSE: 0.012610716745257378, epsilon: 0.8, 100 steps reward: 0.16
# epoch:161,  MSE: 0.025862865149974823, epsilon: 0.8, 100 steps reward: 0.16
# epoch:162,  MSE: 0.028871947899460793, epsilon: 0.8, 100 steps reward: 0.16
# epoch:163,  MSE: 0.030554188415408134, epsilon: 0.8, 100 steps reward: 0.16
# epoch:164,  MSE: 0.022697074338793755, epsilon: 0.8, 100 steps reward: 0.16
# epoch:165,  MSE: 0.022441506385803223, epsilon: 0.8, 100 steps reward: 0.16
# epoch:166,  MSE: 0.019112437963485718, epsilon: 0.8, 100 steps reward: 0.16
# epoch:167,  MSE: 0.011925555765628815, epsilon: 0.8, 100 steps reward: 0.16
# epoch:168,  MSE: 0.020878106355667114, epsilon: 0.8, 100 steps reward: 0.16
# epoch:169,  MSE: 0.014563784934580326, epsilon: 0.8, 100 steps reward: 0.16
# epoch:170,  MSE: 0.011400090530514717, epsilon: 0.8, 100 steps reward: 0.0
# epoch:171,  MSE: 0.009474311023950577, epsilon: 0.8, 100 steps reward: 0.0
# epoch:172,  MSE: 0.014128055423498154, epsilon: 0.8, 100 steps reward: 0.0
# epoch:173,  MSE: 0.010608467273414135, epsilon: 0.8, 100 steps reward: 0.0
# epoch:174,  MSE: 0.005990653298795223, epsilon: 0.8, 100 steps reward: 0.0
# epoch:175,  MSE: 0.00514958193525672, epsilon: 0.8, 100 steps reward: 0.0
# epoch:176,  MSE: 0.006344953551888466, epsilon: 0.8, 100 steps reward: 0.0
# epoch:177,  MSE: 0.010972809977829456, epsilon: 0.8, 100 steps reward: 0.0
# epoch:178,  MSE: 0.007619636133313179, epsilon: 0.8, 100 steps reward: 0.0
# epoch:179,  MSE: 0.005171927157789469, epsilon: 0.8, 100 steps reward: 0.0
# epoch:180,  MSE: 0.0048667192459106445, epsilon: 0.8, 100 steps reward: 0.0
# epoch:181,  MSE: 0.007617941591888666, epsilon: 0.8, 100 steps reward: 0.0
# epoch:182,  MSE: 0.00925352517515421, epsilon: 0.8, 100 steps reward: 0.0
# epoch:183,  MSE: 0.007086053024977446, epsilon: 0.8, 100 steps reward: 0.0
# epoch:184,  MSE: 0.0047447094693779945, epsilon: 0.8, 100 steps reward: 0.0
# epoch:185,  MSE: 0.0037478329613804817, epsilon: 0.8, 100 steps reward: 0.0
# epoch:186,  MSE: 0.006846618372946978, epsilon: 0.8, 100 steps reward: 0.0
# epoch:187,  MSE: 0.005446567200124264, epsilon: 0.8, 100 steps reward: 0.0
# epoch:188,  MSE: 0.0059765176847577095, epsilon: 0.8, 100 steps reward: 0.0
# epoch:189,  MSE: 0.00510005047544837, epsilon: 0.8, 100 steps reward: 0.0
# epoch:190,  MSE: 0.0036119758151471615, epsilon: 0.8, 100 steps reward: 0.0
# epoch:191,  MSE: 0.005558833945542574, epsilon: 0.8, 100 steps reward: 0.0
# epoch:192,  MSE: 0.005948955658823252, epsilon: 0.8, 100 steps reward: 0.0
# epoch:193,  MSE: 0.003043479984626174, epsilon: 0.8, 100 steps reward: 0.0
# epoch:194,  MSE: 0.0010436378652229905, epsilon: 0.8, 100 steps reward: 0.0
# epoch:195,  MSE: 0.007163323927670717, epsilon: 0.8, 100 steps reward: 0.0
# epoch:196,  MSE: 0.006147277541458607, epsilon: 0.8, 100 steps reward: 0.0
# epoch:197,  MSE: 0.004890001378953457, epsilon: 0.8, 100 steps reward: 0.0
# epoch:198,  MSE: 0.005579615477472544, epsilon: 0.8, 100 steps reward: 0.0
# epoch:199,  MSE: 0.020682813599705696, epsilon: 0.8, 100 steps reward: 0.0

# %% [markdown]
# # 可视化预测

# %%
# DQN_Q = dqn.net

# env = frozen_lake.FrozenLakeEnv(is_slippery=False, render_mode="human")
# env.spec = gym.spec("FrozenLake-v1")
# # display_size = 512
# # env.window_size = (display_size, display_size)
# # env.cell_size = (
# #     env.window_size[0] // env.ncol,
# #     env.window_size[1] // env.nrow,
# # )
# env = gym.wrappers.RecordVideo(env, video_folder="video")

# env = DiscreteOneHotWrapper(env)

# state, info = env.reset()
# total_rewards = 0

# while True:
#     action = int(torch.argmax(DQN_Q(torch.Tensor(state))))
#     state, reward, terminated, truncted, info = env.step(action)
#     print(action)
#     if terminated:
#         break
# env.close()
